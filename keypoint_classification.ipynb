# %%
# !git clone https://github.com/Kazuhito00/hand-gesture-recognition-using-mediapipe.git
# Out:
# Cloning into 'hand-gesture-recognition-using-mediapipe'...
# remote: Enumerating objects: 182, done.
# remote: Counting objects: 100% (76/76), done.
# remote: Compressing objects: 100% (29/29), done.
# remote: Total 182 (delta 60), reused 47 (delta 47), pack-reused 106 (from 1)
# Receiving objects: 100% (182/182), 1.05 MiB | 3.52 MiB/s, done.
# Resolving deltas: 100% (97/97), done.

# %%
import csv

import numpy as np
import tensorflow as tf
from sklearn.model_selection import train_test_split

RANDOM_SEED = 42

# %% [markdown]
# # 各パス指定

# %%
dataset = 'hand-gesture-recognition-using-mediapipe/model/keypoint_classifier/keypoint.csv'
model_save_path = 'model/keypoint_classifier/keypoint_classifier.keras'

# %% [markdown]
# # 分類数設定

# %%
NUM_CLASSES = 3

# %% [markdown]
# # 学習データ読み込み

# %%
X_dataset = np.loadtxt(dataset, delimiter=',', dtype='float32', usecols=list(range(1, (21 * 2) + 1)))

# %%
y_dataset = np.loadtxt(dataset, delimiter=',', dtype='int32', usecols=(0))

# %%
X_train, X_test, y_train, y_test = train_test_split(X_dataset, y_dataset, train_size=0.75, random_state=RANDOM_SEED)

# %% [markdown]
# # モデル構築

# %%
model = tf.keras.models.Sequential([
    tf.keras.layers.Input((21 * 2, )),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Dense(20, activation='relu'),
    tf.keras.layers.Dropout(0.4),
    tf.keras.layers.Dense(10, activation='relu'),
    tf.keras.layers.Dense(NUM_CLASSES, activation='softmax')
])

# %%
model.summary()  # tf.keras.utils.plot_model(model, show_shapes=True)
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dropout (Dropout)               │ (None, 42)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 20)             │           860 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 20)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 10)             │           210 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 3)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,103 (4.31 KB)
#  Trainable params: 1,103 (4.31 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# モデルチェックポイントのコールバック
cp_callback = tf.keras.callbacks.ModelCheckpoint(
    model_save_path, verbose=1, save_weights_only=False)
# 早期打ち切り用コールバック
es_callback = tf.keras.callbacks.EarlyStopping(patience=20, verbose=1)

# %%
# モデルコンパイル
model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# %% [markdown]
# # モデル訓練

# %%
model.fit(
    X_train,
    y_train,
    epochs=1000,
    batch_size=128,
    validation_data=(X_test, y_test),
    callbacks=[cp_callback, es_callback]
)
# Out:
# Epoch 1/1000
#  1/27 ━━━━━━━━━━━━━━━━━━━━ 30s 1s/step - accuracy: 0.3047 - loss: 1.2824
# Epoch 1: saving model to model/keypoint_classifier/keypoint_classifier.keras
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.3236 - loss: 1.1955 - val_accuracy: 0.4142 - val_loss: 1.0632
# Epoch 2/1000
#  1/27 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.3828 - loss: 1.0748
# Epoch 2: saving model to model/keypoint_classifier/keypoint_classifier.keras
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.3858 - loss: 1.0883 - val_accuracy: 0.4681 - val_loss: 1.0235
# Epoch 3/1000
# 24/27 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4154 - loss: 1.0614
# Epoch 3: saving model to model/keypoint_classifier/keypoint_classifier.keras
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.4184 - loss: 1.0597 - val_accuracy: 0.5274 - val_loss: 0.9849
# Epoch 4/1000
#  1/27 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.4453 - loss: 1.0579
# Epoch 4: saving model to model/keypoint_classifier/keypoint_classifier.keras
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.4695 - loss: 1.0279 - val_accuracy: 0.5921 - val_loss: 0.9431
# Epoch 5/1000
# 19/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5041 - loss: 0.9927
# Epoch 5: saving model to model/keypoint_classifier/keypoint_classifier.keras
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5109 - loss: 0.9874 - val_accuracy: 0.6568 - val_loss: 0.8913
# Epoch 6/1000
# 21/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5391 - loss: 0.9462
# Epoch 6: saving model to model/keypoint_classifier/keypoint_classifier.keras
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5424 - loss: 0.9445 - val_accuracy: 0.7062 - val_loss: 0.8410
# Epoch 7/1000
# 19/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5646 - loss: 0.9173
# Epoch 7: saving model to model/keypoint_classifier/keypoint_classifier.keras
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.5673 - loss: 0.9145 - val_accuracy: 0.8122 - val_loss: 0.7851
# Epoch 8/1000
# 26/27 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5756 - loss: 0.8852
# Epoch 8: saving model to model/keypoint_classifier/keypoint_classifier.keras
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 0.5774 - loss: 0.8844 - val_accuracy: 0.8284 - val_loss: 0.7347
# Epoch 9/1000
# 23/27 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6178 - loss: 0.8474
# Epoch 9: saving model to model/keypoint_classifier/keypoint_classifier.keras
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.6168 - loss: 0.8472 - val_accuracy: 0.8185 - val_loss: 0.6947
# Epoch 10/1000
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6277 - loss: 0.8259
# Epoch 10: saving model to model/keypoint_classifier/keypoint_classifier.keras
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.6277 - loss: 0.8258 - val_accuracy: 0.8311 - val_loss: 0.6545
# Epoch 11/1000
# 19/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6277 - loss: 0.8093
# Epoch 11: saving model to model/keypoint_classifier/keypoint_classifier.keras
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.6290 - loss: 0.8073 - val_accuracy: 0.8284 - val_loss: 0.6334
# Epoch 12/1000
# 25/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6643 - loss: 0.7718
# Epoch 12: saving model to model/keypoint_classifier/keypoint_classifier.keras
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.6637 - loss: 0.7718 - val_accuracy: 0.8374 - val_loss: 0.6001
# Epoch 13/1000
# 22/27 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6690 - loss: 0.7495
# Epoch 13: saving model to model/keypoint_classifier/keypoint_classifier.keras
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.6693 - loss: 0.7482 - val_accuracy: 0.8509 - val_loss: 0.5648
# Epoch 14/1000
# 19/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6675 - loss: 0.7376
# Epoch 14: saving model to model/keypoint_classifier/keypoint_classifier.keras
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.6682 - loss: 0.7388 - val_accuracy: 0.8724 - val_loss: 0.5357
# Epoch 15/1000
# 23/27 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6905 - loss: 0.7311
# Epoch 15: saving model to model/keypoint_classifier/keypoint_classifier.keras
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.6913 - loss: 0.7294 - val_accuracy: 0.8805 - val_loss: 0.5166
# Epoch 16/1000
#  1/27 ━━━━━━━━━━━━━━━━━━━━ 4s 184ms/step - accuracy: 0.6484 - loss: 0.7537
# Epoch 16: saving model to model/keypoint_classifier/keypoint_classifier.keras
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6902 - loss: 0.7253 - val_accuracy: 0.8832 - val_loss: 0.4924
# Epoch 17/1000
# 26/27 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6893 - loss: 0.7080
# Epoch 17: saving model to model/keypoint_classifier/keypoint_classifier.keras
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6896 - loss: 0.7080 - val_accuracy: 0.8931 - val_loss: 0.4752
# Epoch 18/1000
#  1/27 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.7109 - loss: 0.7355
# Epoch 18: saving model to model/keypoint_classifier/keypoint_classifier.keras
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7037 - loss: 0.6986 - val_accuracy: 0.9057 - val_loss: 0.4512
# Epoch 19/1000
#  1/27 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.6719 - loss: 0.6684
# Epoch 19: saving model to model/keypoint_classifier/keypoint_classifier.keras
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7032 - loss: 0.6814 - val_accuracy: 0.9137 - val_loss: 0.4410
# Epoch 20/1000
#  1/27 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.6953 - loss: 0.6520
# Epoch 20: saving model to model/keypoint_classifier/keypoint_classifier.keras
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7237 - loss: 0.6704 - val_accuracy: 0.9245 - val_loss: 0.4191
# Epoch 21/1000
#  1/27 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.7109 - loss: 0.6737
# Epoch 21: saving model to model/keypoint_classifier/keypoint_classifier.keras
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7341 - loss: 0.6462 - val_accuracy: 0.9308 - val_loss: 0.3975
# Epoch 22/1000
#  1/27 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.7656 - loss: 0.6307
# Epoch 22: saving model to model/keypoint_classifier/keypoint_classifier.keras
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7474 - loss: 0.6404 - val_accuracy: 0.9317 - val_loss: 0.3820
# Epoch 23/1000
#  1/27 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.7188 - loss: 0.6348
# Epoch 23: saving model to model/keypoint_classifier/keypoint_classifier.keras
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7343 - loss: 0.6412 - val_accuracy: 0.9317 - val_loss: 0.3716
# Epoch 24/1000
#  1/27 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.7969 - loss: 0.5672
# Epoch 24: saving model to model/keypoint_classifier/keypoint_classifier.keras
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7545 - loss: 0.6116 - val_accuracy: 0.9380 - val_loss: 0.3661
# Epoch 25/1000
# 26/27 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7466 - loss: 0.6108
# Epoch 25: saving model to model/keypoint_classifier/keypoint_classifier.keras
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7467 - loss: 0.6111 - val_accuracy: 0.9416 - val_loss: 0.3479
# Epoch 26/1000
#  1/27 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.7188 - loss: 0.6398
# Epoch 26: saving model to model/keypoint_classifier/keypoint_classifier.keras
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7513 - loss: 0.6122 - val_accuracy: 0.9371 - val_loss: 0.3465
# Epoch 27/1000
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7711 - loss: 0.5857
# Epoch 27: saving model to model/keypoint_classifier/keypoint_classifier.keras
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7709 - loss: 0.5859 - val_accuracy: 0.9407 - val_loss: 0.3335
# Epoch 28/1000
# 26/27 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7578 - loss: 0.5989
# Epoch 28: saving model to model/keypoint_classifier/keypoint_classifier.keras
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7581 - loss: 0.5989 - val_accuracy: 0.9416 - val_loss: 0.3309
# Epoch 29/1000
#  1/27 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.7188 - loss: 0.6567
# Epoch 29: saving model to model/keypoint_classifier/keypoint_classifier.keras
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7625 - loss: 0.5988 - val_accuracy: 0.9407 - val_loss: 0.3221
# Epoch 30/1000
# 21/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7879 - loss: 0.5587
# Epoch 30: saving model to model/keypoint_classifier/keypoint_classifier.keras
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7845 - loss: 0.5627 - val_accuracy: 0.9497 - val_loss: 0.3062
# Epoch 31/1000
#  1/27 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.7422 - loss: 0.6143
# Epoch 31: saving model to model/keypoint_classifier/keypoint_classifier.keras
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7588 - loss: 0.5863 - val_accuracy: 0.9461 - val_loss: 0.3022
# Epoch 32/1000
#  1/27 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.7109 - loss: 0.6644
# Epoch 32: saving model to model/keypoint_classifier/keypoint_classifier.keras
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7649 - loss: 0.5821 - val_accuracy: 0.9479 - val_loss: 0.2996
# Epoch 33/1000
#  1/27 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.8125 - loss: 0.5243
# Epoch 33: saving model to model/keypoint_classifier/keypoint_classifier.keras
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7715 - loss: 0.5698 - val_accuracy: 0.9569 - val_loss: 0.2923
# Epoch 34/1000
#  1/27 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.7891 - loss: 0.5216
# Epoch 34: saving model to model/keypoint_classifier/keypoint_classifier.keras
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7724 - loss: 0.5612 - val_accuracy: 0.9569 - val_loss: 0.2853
# Epoch 35/1000
#  1/27 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.7656 - loss: 0.5704
# Epoch 35: saving model to model/keypoint_classifier/keypoint_classifier.keras
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7869 - loss: 0.5483 - val_accuracy: 0.9560 - val_loss: 0.2817
# Epoch 36/1000
# 22/27 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7822 - loss: 0.5436
# Epoch 36: saving model to model/keypoint_classifier/keypoint_classifier.keras
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7797 - loss: 0.5474 - val_accuracy: 0.9515 - val_loss: 0.2792
# Epoch 37/1000
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7845 - loss: 0.5436
# Epoch 37: saving model to model/keypoint_classifier/keypoint_classifier.keras
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7845 - loss: 0.5435 - val_accuracy: 0.9587 - val_loss: 0.2746
# Epoch 38/1000
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7826 - loss: 0.5484
# Epoch 38: saving model to model/keypoint_classifier/keypoint_classifier.keras
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7827 - loss: 0.5481 - val_accuracy: 0.9596 - val_loss: 0.2704
# Epoch 39/1000
#  1/27 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.8047 - loss: 0.5125
# Epoch 39: saving model to model/keypoint_classifier/keypoint_classifier.keras
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7939 - loss: 0.5384 - val_accuracy: 0.9614 - val_loss: 0.2627
# Epoch 40/1000
#  1/27 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.7891 - loss: 0.6037
# Epoch 40: saving model to model/keypoint_classifier/keypoint_classifier.keras
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8040 - loss: 0.5215 - val_accuracy: 0.9641 - val_loss: 0.2583
# Epoch 41/1000
#  1/27 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.7344 - loss: 0.6932
# Epoch 41: saving model to model/keypoint_classifier/keypoint_classifier.keras
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7878 - loss: 0.5470 - val_accuracy: 0.9632 - val_loss: 0.2573
# Epoch 42/1000
#  1/27 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.6953 - loss: 0.5861
# Epoch 42: saving model to model/keypoint_classifier/keypoint_classifier.keras
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7873 - loss: 0.5205 - val_accuracy: 0.9632 - val_loss: 0.2558
# Epoch 43/1000
#  1/27 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.7734 - loss: 0.5591
# Epoch 43: saving model to model/keypoint_classifier/keypoint_classifier.keras
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7882 - loss: 0.5284 - val_accuracy: 0.9632 - val_loss: 0.2504
# Epoch 44/1000
#  1/27 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.7500 - loss: 0.5886
# Epoch 44: saving model to model/keypoint_classifier/keypoint_classifier.keras
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7862 - loss: 0.5363 - val_accuracy: 0.9623 - val_loss: 0.2444
# Epoch 45/1000
#  1/27 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8516 - loss: 0.4154
# Epoch 45: saving model to model/keypoint_classifier/keypoint_classifier.keras
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8081 - loss: 0.4966 - val_accuracy: 0.9596 - val_loss: 0.2442
# Epoch 46/1000
#  1/27 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.7578 - loss: 0.5477
# Epoch 46: saving model to model/keypoint_classifier/keypoint_classifier.keras
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7977 - loss: 0.5063 - val_accuracy: 0.9623 - val_loss: 0.2363
# Epoch 47/1000
#  1/27 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.8047 - loss: 0.4820
# Epoch 47: saving model to model/keypoint_classifier/keypoint_classifier.keras
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8024 - loss: 0.5026 - val_accuracy: 0.9659 - val_loss: 0.2321
# Epoch 48/1000
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8078 - loss: 0.4877
# Epoch 48: saving model to model/keypoint_classifier/keypoint_classifier.keras
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8079 - loss: 0.4876 - val_accuracy: 0.9632 - val_loss: 0.2341
# Epoch 49/1000
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8016 - loss: 0.4920
# Epoch 49: saving model to model/keypoint_classifier/keypoint_classifier.keras
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8017 - loss: 0.4919 - val_accuracy: 0.9632 - val_loss: 0.2333
# Epoch 50/1000
# 26/27 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8037 - loss: 0.5031
# Epoch 50: saving model to model/keypoint_classifier/keypoint_classifier.keras
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8038 - loss: 0.5034 - val_accuracy: 0.9668 - val_loss: 0.2336
# Epoch 51/1000
#  1/27 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8047 - loss: 0.4476
# Epoch 51: saving model to model/keypoint_classifier/keypoint_classifier.keras
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8016 - loss: 0.4965 - val_accuracy: 0.9650 - val_loss: 0.2300
# Epoch 52/1000
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8248 - loss: 0.4776
# Epoch 52: saving model to model/keypoint_classifier/keypoint_classifier.keras
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8245 - loss: 0.4774 - val_accuracy: 0.9650 - val_loss: 0.2248
# Epoch 53/1000
#  1/27 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.7969 - loss: 0.5168
# Epoch 53: saving model to model/keypoint_classifier/keypoint_classifier.keras
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8014 - loss: 0.5015 - val_accuracy: 0.9650 - val_loss: 0.2272
# Epoch 54/1000
#  1/27 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.8672 - loss: 0.4700
# Epoch 54: saving model to model/keypoint_classifier/keypoint_classifier.keras
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8237 - loss: 0.4818 - val_accuracy: 0.9650 - val_loss: 0.2231
# Epoch 55/1000
#  1/27 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.7969 - loss: 0.4822
# Epoch 55: saving model to model/keypoint_classifier/keypoint_classifier.keras
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8165 - loss: 0.4769 - val_accuracy: 0.9677 - val_loss: 0.2119
# Epoch 56/1000
#  1/27 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.7891 - loss: 0.4888
# Epoch 56: saving model to model/keypoint_classifier/keypoint_classifier.keras
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8082 - loss: 0.4948 - val_accuracy: 0.9695 - val_loss: 0.2129
# Epoch 57/1000
#  1/27 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.8047 - loss: 0.4309
# Epoch 57: saving model to model/keypoint_classifier/keypoint_classifier.keras
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8013 - loss: 0.4992 - val_accuracy: 0.9659 - val_loss: 0.2217
# Epoch 58/1000
# 22/27 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8128 - loss: 0.4832
# Epoch 58: saving model to model/keypoint_classifier/keypoint_classifier.keras
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8132 - loss: 0.4839 - val_accuracy: 0.9614 - val_loss: 0.2266
# Epoch 59/1000
# 20/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8109 - loss: 0.4871
# Epoch 59: saving model to model/keypoint_classifier/keypoint_classifier.keras
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8111 - loss: 0.4870 - val_accuracy: 0.9668 - val_loss: 0.2228
# Epoch 60/1000
# 17/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8003 - loss: 0.5134
# Epoch 60: saving model to model/keypoint_classifier/keypoint_classifier.keras
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8061 - loss: 0.4979 - val_accuracy: 0.9650 - val_loss: 0.2150
# Epoch 61/1000
# 22/27 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8162 - loss: 0.4667
# Epoch 61: saving model to model/keypoint_classifier/keypoint_classifier.keras
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8172 - loss: 0.4656 - val_accuracy: 0.9614 - val_loss: 0.2127
# Epoch 62/1000
# 18/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8088 - loss: 0.4796
# Epoch 62: saving model to model/keypoint_classifier/keypoint_classifier.keras
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8100 - loss: 0.4753 - val_accuracy: 0.9668 - val_loss: 0.2075
# Epoch 63/1000
# 20/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8221 - loss: 0.4518
# Epoch 63: saving model to model/keypoint_classifier/keypoint_classifier.keras
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8234 - loss: 0.4516 - val_accuracy: 0.9704 - val_loss: 0.2112
# Epoch 64/1000
# 18/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8049 - loss: 0.5026
# Epoch 64: saving model to model/keypoint_classifier/keypoint_classifier.keras
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8088 - loss: 0.4939 - val_accuracy: 0.9677 - val_loss: 0.2086
# Epoch 65/1000
# 16/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8330 - loss: 0.4552
# Epoch 65: saving model to model/keypoint_classifier/keypoint_classifier.keras
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8295 - loss: 0.4577 - val_accuracy: 0.9712 - val_loss: 0.2033
# Epoch 66/1000
# 14/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8375 - loss: 0.4272
# Epoch 66: saving model to model/keypoint_classifier/keypoint_classifier.keras
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8329 - loss: 0.4409 - val_accuracy: 0.9695 - val_loss: 0.1997
# Epoch 67/1000
# 15/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8168 - loss: 0.4377
# Epoch 67: saving model to model/keypoint_classifier/keypoint_classifier.keras
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8190 - loss: 0.4438 - val_accuracy: 0.9712 - val_loss: 0.1956
# Epoch 68/1000
#  1/27 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.8047 - loss: 0.4798
# Epoch 68: saving model to model/keypoint_classifier/keypoint_classifier.keras
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8218 - loss: 0.4785 - val_accuracy: 0.9712 - val_loss: 0.1986
# Epoch 69/1000
#  1/27 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.8672 - loss: 0.3953
# Epoch 69: saving model to model/keypoint_classifier/keypoint_classifier.keras
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8406 - loss: 0.4364 - val_accuracy: 0.9712 - val_loss: 0.1968
# Epoch 70/1000
#  1/27 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.7969 - loss: 0.4436
# Epoch 70: saving model to model/keypoint_classifier/keypoint_classifier.keras
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8147 - loss: 0.4729 - val_accuracy: 0.9641 - val_loss: 0.1997
# Epoch 71/1000
#  1/27 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.8516 - loss: 0.3298
# Epoch 71: saving model to model/keypoint_classifier/keypoint_classifier.keras
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8166 - loss: 0.4413 - val_accuracy: 0.9704 - val_loss: 0.1971
# Epoch 72/1000
#  1/27 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.8438 - loss: 0.3779
# Epoch 72: saving model to model/keypoint_classifier/keypoint_classifier.keras
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8228 - loss: 0.4543 - val_accuracy: 0.9730 - val_loss: 0.1956
# Epoch 73/1000
#  1/27 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.8359 - loss: 0.5249
# Epoch 73: saving model to model/keypoint_classifier/keypoint_classifier.keras
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8227 - loss: 0.5006 - val_accuracy: 0.9704 - val_loss: 0.1920
# Epoch 74/1000
#  1/27 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.8359 - loss: 0.4414
# Epoch 74: saving model to model/keypoint_classifier/keypoint_classifier.keras
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8360 - loss: 0.4293 - val_accuracy: 0.9677 - val_loss: 0.1994
# Epoch 75/1000
#  1/27 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8281 - loss: 0.4827
# Epoch 75: saving model to model/keypoint_classifier/keypoint_classifier.keras
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8242 - loss: 0.4604 - val_accuracy: 0.9704 - val_loss: 0.1990
# Epoch 76/1000
#  1/27 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.8359 - loss: 0.4394
# Epoch 76: saving model to model/keypoint_classifier/keypoint_classifier.keras
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8329 - loss: 0.4242 - val_accuracy: 0.9730 - val_loss: 0.1928
# Epoch 77/1000
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8314 - loss: 0.4361
# Epoch 77: saving model to model/keypoint_classifier/keypoint_classifier.keras
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8314 - loss: 0.4364 - val_accuracy: 0.9704 - val_loss: 0.1952
# Epoch 78/1000
#  1/27 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.8516 - loss: 0.4690
# Epoch 78: saving model to model/keypoint_classifier/keypoint_classifier.keras
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8453 - loss: 0.4411 - val_accuracy: 0.9704 - val_loss: 0.1892
# Epoch 79/1000
#  1/27 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.8203 - loss: 0.5029
# Epoch 79: saving model to model/keypoint_classifier/keypoint_classifier.keras
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8414 - loss: 0.4363 - val_accuracy: 0.9712 - val_loss: 0.1875
# Epoch 80/1000
#  1/27 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.8828 - loss: 0.3527
# Epoch 80: saving model to model/keypoint_classifier/keypoint_classifier.keras
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8286 - loss: 0.4363 - val_accuracy: 0.9730 - val_loss: 0.1855
# Epoch 81/1000
#  1/27 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.7969 - loss: 0.5119
# Epoch 81: saving model to model/keypoint_classifier/keypoint_classifier.keras
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8250 - loss: 0.4469 - val_accuracy: 0.9748 - val_loss: 0.1868
# Epoch 82/1000
#  1/27 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.8672 - loss: 0.4011
# Epoch 82: saving model to model/keypoint_classifier/keypoint_classifier.keras
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8343 - loss: 0.4421 - val_accuracy: 0.9721 - val_loss: 0.1906
# Epoch 83/1000
#  1/27 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.8125 - loss: 0.5276
# Epoch 83: saving model to model/keypoint_classifier/keypoint_classifier.keras
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8273 - loss: 0.4550 - val_accuracy: 0.9659 - val_loss: 0.1916
# Epoch 84/1000
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8203 - loss: 0.4447
# Epoch 84: saving model to model/keypoint_classifier/keypoint_classifier.keras
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8207 - loss: 0.4444 - val_accuracy: 0.9748 - val_loss: 0.1861
# Epoch 85/1000
#  1/27 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.8125 - loss: 0.4100
# Epoch 85: saving model to model/keypoint_classifier/keypoint_classifier.keras
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8326 - loss: 0.4278 - val_accuracy: 0.9748 - val_loss: 0.1884
# Epoch 86/1000
#  1/27 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.8750 - loss: 0.4187
# Epoch 86: saving model to model/keypoint_classifier/keypoint_classifier.keras
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8255 - loss: 0.4445 - val_accuracy: 0.9730 - val_loss: 0.1921
# Epoch 87/1000
#  1/27 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.8047 - loss: 0.5320
# Epoch 87: saving model to model/keypoint_classifier/keypoint_classifier.keras
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8224 - loss: 0.4540 - val_accuracy: 0.9757 - val_loss: 0.1921
# Epoch 88/1000
#  1/27 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.8359 - loss: 0.4119
# Epoch 88: saving model to model/keypoint_classifier/keypoint_classifier.keras
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8335 - loss: 0.4333 - val_accuracy: 0.9766 - val_loss: 0.1875
# Epoch 89/1000
# 26/27 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8145 - loss: 0.4586
# Epoch 89: saving model to model/keypoint_classifier/keypoint_classifier.keras
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8156 - loss: 0.4577 - val_accuracy: 0.9757 - val_loss: 0.1924
# Epoch 90/1000
# 23/27 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8499 - loss: 0.3898
# Epoch 90: saving model to model/keypoint_classifier/keypoint_classifier.keras
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8466 - loss: 0.3967 - val_accuracy: 0.9784 - val_loss: 0.1895
# Epoch 91/1000
#  1/27 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.8281 - loss: 0.4275
# Epoch 91: saving model to model/keypoint_classifier/keypoint_classifier.keras
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8245 - loss: 0.4415 - val_accuracy: 0.9748 - val_loss: 0.1910
# Epoch 92/1000
#  1/27 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.8672 - loss: 0.3628
# Epoch 92: saving model to model/keypoint_classifier/keypoint_classifier.keras
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8400 - loss: 0.4112 - val_accuracy: 0.9757 - val_loss: 0.1903
# Epoch 93/1000
#  1/27 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.8281 - loss: 0.4432
# Epoch 93: saving model to model/keypoint_classifier/keypoint_classifier.keras
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8412 - loss: 0.4201 - val_accuracy: 0.9712 - val_loss: 0.1865
# Epoch 94/1000
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8227 - loss: 0.4656
# Epoch 94: saving model to model/keypoint_classifier/keypoint_classifier.keras
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8231 - loss: 0.4648 - val_accuracy: 0.9730 - val_loss: 0.1859
# Epoch 95/1000
#  1/27 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.8359 - loss: 0.3993
# Epoch 95: saving model to model/keypoint_classifier/keypoint_classifier.keras
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8349 - loss: 0.4148 - val_accuracy: 0.9641 - val_loss: 0.1897
# Epoch 96/1000
# 22/27 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8328 - loss: 0.4537
# Epoch 96: saving model to model/keypoint_classifier/keypoint_classifier.keras
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8325 - loss: 0.4498 - val_accuracy: 0.9775 - val_loss: 0.1846
# Epoch 97/1000
#  1/27 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.8281 - loss: 0.4460
# Epoch 97: saving model to model/keypoint_classifier/keypoint_classifier.keras
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8394 - loss: 0.4187 - val_accuracy: 0.9730 - val_loss: 0.1827
# Epoch 98/1000
#  1/27 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.8516 - loss: 0.4572
# Epoch 98: saving model to model/keypoint_classifier/keypoint_classifier.keras
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8219 - loss: 0.4579 - val_accuracy: 0.9721 - val_loss: 0.1822
# Epoch 99/1000
#  1/27 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.8438 - loss: 0.4372
# Epoch 99: saving model to model/keypoint_classifier/keypoint_classifier.keras
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8321 - loss: 0.4286 - val_accuracy: 0.9668 - val_loss: 0.1803
# Epoch 100/1000
#  1/27 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.8828 - loss: 0.3144
# Epoch 100: saving model to model/keypoint_classifier/keypoint_classifier.keras
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8458 - loss: 0.4264 - val_accuracy: 0.9677 - val_loss: 0.1786
# Epoch 101/1000
#  1/27 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.8203 - loss: 0.4141
# Epoch 101: saving model to model/keypoint_classifier/keypoint_classifier.keras
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8324 - loss: 0.4206 - val_accuracy: 0.9721 - val_loss: 0.1837
# Epoch 102/1000
# 25/27 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8301 - loss: 0.4300
# Epoch 102: saving model to model/keypoint_classifier/keypoint_classifier.keras
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8303 - loss: 0.4301 - val_accuracy: 0.9757 - val_loss: 0.1790
# Epoch 103/1000
#  1/27 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.8516 - loss: 0.3981
# Epoch 103: saving model to model/keypoint_classifier/keypoint_classifier.keras
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8504 - loss: 0.3971 - val_accuracy: 0.9748 - val_loss: 0.1721
# Epoch 104/1000
#  1/27 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.8203 - loss: 0.4735
# Epoch 104: saving model to model/keypoint_classifier/keypoint_classifier.keras
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8424 - loss: 0.4220 - val_accuracy: 0.9748 - val_loss: 0.1741
# Epoch 105/1000
#  1/27 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.7969 - loss: 0.4474
# Epoch 105: saving model to model/keypoint_classifier/keypoint_classifier.keras
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8440 - loss: 0.4011 - val_accuracy: 0.9775 - val_loss: 0.1763
# Epoch 106/1000
#  1/27 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.8359 - loss: 0.4112
# Epoch 106: saving model to model/keypoint_classifier/keypoint_classifier.keras
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8482 - loss: 0.4082 - val_accuracy: 0.9748 - val_loss: 0.1733
# Epoch 107/1000
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8536 - loss: 0.4158
# Epoch 107: saving model to model/keypoint_classifier/keypoint_classifier.keras
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8533 - loss: 0.4161 - val_accuracy: 0.9757 - val_loss: 0.1766
# Epoch 108/1000
#  1/27 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - accuracy: 0.8438 - loss: 0.4299
# Epoch 108: saving model to model/keypoint_classifier/keypoint_classifier.keras
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8311 - loss: 0.4328 - val_accuracy: 0.9677 - val_loss: 0.1817
# Epoch 109/1000
#  1/27 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.8438 - loss: 0.5041
# Epoch 109: saving model to model/keypoint_classifier/keypoint_classifier.keras
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8421 - loss: 0.4240 - val_accuracy: 0.9793 - val_loss: 0.1693
# Epoch 110/1000
#  1/27 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.8359 - loss: 0.4403
# Epoch 110: saving model to model/keypoint_classifier/keypoint_classifier.keras
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8443 - loss: 0.4117 - val_accuracy: 0.9793 - val_loss: 0.1668
# Epoch 111/1000
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8436 - loss: 0.4362
# Epoch 111: saving model to model/keypoint_classifier/keypoint_classifier.keras
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8435 - loss: 0.4357 - val_accuracy: 0.9766 - val_loss: 0.1720
# Epoch 112/1000
#  1/27 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.8281 - loss: 0.3857
# Epoch 112: saving model to model/keypoint_classifier/keypoint_classifier.keras
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8527 - loss: 0.3882 - val_accuracy: 0.9748 - val_loss: 0.1716
# Epoch 113/1000
# 26/27 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8422 - loss: 0.4073
# Epoch 113: saving model to model/keypoint_classifier/keypoint_classifier.keras
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8422 - loss: 0.4074 - val_accuracy: 0.9721 - val_loss: 0.1634
# Epoch 114/1000
#  1/27 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.8359 - loss: 0.3487
# Epoch 114: saving model to model/keypoint_classifier/keypoint_classifier.keras
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8252 - loss: 0.4313 - val_accuracy: 0.9784 - val_loss: 0.1640
# Epoch 115/1000
# 26/27 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8460 - loss: 0.4177
# Epoch 115: saving model to model/keypoint_classifier/keypoint_classifier.keras
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8463 - loss: 0.4162 - val_accuracy: 0.9739 - val_loss: 0.1675
# Epoch 116/1000
#  1/27 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.8672 - loss: 0.3924
# Epoch 116: saving model to model/keypoint_classifier/keypoint_classifier.keras
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8347 - loss: 0.4272 - val_accuracy: 0.9775 - val_loss: 0.1660
# Epoch 117/1000
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8481 - loss: 0.4082
# Epoch 117: saving model to model/keypoint_classifier/keypoint_classifier.keras
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8481 - loss: 0.4079 - val_accuracy: 0.9686 - val_loss: 0.1830
# Epoch 118/1000
#  1/27 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.7891 - loss: 0.5447
# Epoch 118: saving model to model/keypoint_classifier/keypoint_classifier.keras
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8196 - loss: 0.4638 - val_accuracy: 0.9712 - val_loss: 0.1736
# Epoch 119/1000
#  1/27 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.8750 - loss: 0.3783
# Epoch 119: saving model to model/keypoint_classifier/keypoint_classifier.keras
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8438 - loss: 0.4079 - val_accuracy: 0.9695 - val_loss: 0.1724
# Epoch 120/1000
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8474 - loss: 0.3924
# Epoch 120: saving model to model/keypoint_classifier/keypoint_classifier.keras
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8475 - loss: 0.3929 - val_accuracy: 0.9659 - val_loss: 0.1774
# Epoch 121/1000
#  1/27 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.8594 - loss: 0.3923
# Epoch 121: saving model to model/keypoint_classifier/keypoint_classifier.keras
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8497 - loss: 0.3917 - val_accuracy: 0.9695 - val_loss: 0.1744
# Epoch 122/1000
# 22/27 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8540 - loss: 0.3851
# Epoch 122: saving model to model/keypoint_classifier/keypoint_classifier.keras
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8539 - loss: 0.3858 - val_accuracy: 0.9686 - val_loss: 0.1736
# Epoch 123/1000
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8544 - loss: 0.3794
# Epoch 123: saving model to model/keypoint_classifier/keypoint_classifier.keras
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8544 - loss: 0.3796 - val_accuracy: 0.9712 - val_loss: 0.1730
# Epoch 124/1000
# 26/27 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8513 - loss: 0.4012
# Epoch 124: saving model to model/keypoint_classifier/keypoint_classifier.keras
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8508 - loss: 0.4023 - val_accuracy: 0.9677 - val_loss: 0.1756
# Epoch 125/1000
# 13/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8465 - loss: 0.3995
# Epoch 125: saving model to model/keypoint_classifier/keypoint_classifier.keras
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8486 - loss: 0.4013 - val_accuracy: 0.9677 - val_loss: 0.1749
# Epoch 126/1000
# 21/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8497 - loss: 0.4026
# Epoch 126: saving model to model/keypoint_classifier/keypoint_classifier.keras
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8492 - loss: 0.4026 - val_accuracy: 0.9730 - val_loss: 0.1731
# Epoch 127/1000
# 19/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8462 - loss: 0.3988
# Epoch 127: saving model to model/keypoint_classifier/keypoint_classifier.keras
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8470 - loss: 0.4017 - val_accuracy: 0.9748 - val_loss: 0.1718
# Epoch 128/1000
# 18/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8454 - loss: 0.4161
# Epoch 128: saving model to model/keypoint_classifier/keypoint_classifier.keras
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8465 - loss: 0.4114 - val_accuracy: 0.9677 - val_loss: 0.1727
# Epoch 129/1000
# 21/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8448 - loss: 0.3887
# Epoch 129: saving model to model/keypoint_classifier/keypoint_classifier.keras
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8439 - loss: 0.3906 - val_accuracy: 0.9793 - val_loss: 0.1685
# Epoch 130/1000
# 19/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8458 - loss: 0.3886
# Epoch 130: saving model to model/keypoint_classifier/keypoint_classifier.keras
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8492 - loss: 0.3862 - val_accuracy: 0.9721 - val_loss: 0.1671
# Epoch 131/1000
# 22/27 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8542 - loss: 0.4040
# Epoch 131: saving model to model/keypoint_classifier/keypoint_classifier.keras
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8543 - loss: 0.4038 - val_accuracy: 0.9739 - val_loss: 0.1702
# Epoch 132/1000
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8485 - loss: 0.3872
# Epoch 132: saving model to model/keypoint_classifier/keypoint_classifier.keras
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8486 - loss: 0.3872 - val_accuracy: 0.9748 - val_loss: 0.1654
# Epoch 133/1000
# 19/27 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8390 - loss: 0.4242
# Epoch 133: saving model to model/keypoint_classifier/keypoint_classifier.keras
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8405 - loss: 0.4209 - val_accuracy: 0.9704 - val_loss: 0.1657
# Epoch 133: early stopping

# %%
# モデル評価
val_loss, val_acc = model.evaluate(X_test, y_test, batch_size=128)
# Out:
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9752 - loss: 0.1627

# %%
# 保存したモデルのロード
model = tf.keras.models.load_model(model_save_path)

# %%
# 推論テスト
predict_result = model.predict(np.array([X_test[0]]))
print(np.squeeze(predict_result))
print(np.argmax(np.squeeze(predict_result)))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# [0.8789811  0.09229938 0.02871947]
# 0

# %% [markdown]
# # 混同行列

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, classification_report

def print_confusion_matrix(y_true, y_pred, report=True):
    labels = sorted(list(set(y_true)))
    cmx_data = confusion_matrix(y_true, y_pred, labels=labels)

    df_cmx = pd.DataFrame(cmx_data, index=labels, columns=labels)

    fig, ax = plt.subplots(figsize=(7, 6))
    sns.heatmap(df_cmx, annot=True, fmt='g' ,square=False)
    ax.set_ylim(len(set(y_true)), 0)
    plt.show()

    if report:
        print('Classification Report')
        print(classification_report(y_test, y_pred))

Y_pred = model.predict(X_test)
y_pred = np.argmax(Y_pred, axis=1)

print_confusion_matrix(y_test, y_pred)
# Out:
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Classification Report
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      0.99       410
#            1       0.98      0.94      0.96       385
#            2       0.93      0.98      0.95       318
#
#     accuracy                           0.97      1113
#    macro avg       0.97      0.97      0.97      1113
# weighted avg       0.97      0.97      0.97      1113

# %% [markdown]
# # Tensorflow-Lite用のモデルへ変換

# %%
# 推論専用のモデルとして保存
model.save(model_save_path, include_optimizer=False)

# %%
# モデルを変換(量子化)
tflite_save_path = 'model/keypoint_classifier/keypoint_classifier.tflite'

converter = tf.lite.TFLiteConverter.from_keras_model(model)
converter.optimizations = [tf.lite.Optimize.DEFAULT]
tflite_quantized_model = converter.convert()

open(tflite_save_path, 'wb').write(tflite_quantized_model)
# Out:
# Saved artifact at '/tmp/tmpu3ony34u'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 42), dtype=tf.float32, name='input_layer')
# Output Type:
#   TensorSpec(shape=(None, 3), dtype=tf.float32, name=None)
# Captures:
#   136721504645776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136721504639056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136721503716560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136721503716944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136721503715792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136721503727312: TensorSpec(shape=(), dtype=tf.resource, name=None)
# 6512

# %% [markdown]
# # 推論テスト

# %%
interpreter = tf.lite.Interpreter(model_path=tflite_save_path)
interpreter.allocate_tensors()
# Out:
# /usr/local/lib/python3.12/dist-packages/tensorflow/lite/python/interpreter.py:457: UserWarning:     Warning: tf.lite.Interpreter is deprecated and is scheduled for deletion in
#     TF 2.20. Please use the LiteRT interpreter from the ai_edge_litert package.
#     See the [migration guide](https://ai.google.dev/edge/litert/migration)
#     for details.
#
#   warnings.warn(_INTERPRETER_DELETION_WARNING)

# %%
# 入出力テンソルを取得
input_details = interpreter.get_input_details()
output_details = interpreter.get_output_details()

# %%
interpreter.set_tensor(input_details[0]['index'], np.array([X_test[0]]))

# %%
# %%time
# 推論実施
interpreter.invoke()
tflite_results = interpreter.get_tensor(output_details[0]['index'])
# Out:
# CPU times: user 127 µs, sys: 20 µs, total: 147 µs
# Wall time: 240 µs

# %%
print(np.squeeze(tflite_results))
print(np.argmax(np.squeeze(tflite_results)))
# Out:
# [0.8789812  0.09229935 0.02871946]
# 0

# %%
from google.colab import files

files.download(tflite_save_path)
